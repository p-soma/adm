# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
from sklearn.preprocessing import StandardScaler
import uuid 

import adm_load as load
import adm_preproc as pre
import adm_datagen as dg

RANDOM_SEED = 498
# load all transaction data from csv
df = load.transactions()
# Out:
# Using TensorFlow backend.
# /Users/paulsoma/anaconda3/envs/tensorflow/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2901: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
sus_idx = load.get_sus(df)
fraud_idx = load.get_fraud(df)
normal_idx = load.get_norm(df)

# %%
amts_sus = dg.gen_post_amounts(df,sus_idx)
df.update(amts_sus)

# %%
n_sus = len(sus_idx.tolist())
ones_flags = np.ones(n_sus, dtype='int64')
sus_ff = pd.DataFrame({'FraudFlag': ones_flags},index=sus_idx)
df.update(sus_ff)

# %%
dfn = pre.preproc(df)
dfn['POSTAMOUNT'] = StandardScaler().fit_transform(dfn['POSTAMOUNT'].values.reshape(-1, 1))

# %%
dfn.describe()
# Out:
#        PROCESSORACCOUNT    POSTAMOUNT   POSTSUCCESS    HOLDACTION  \
# count      90017.000000  9.001700e+04  90017.000000  90017.000000
# mean         240.864514 -2.525897e-18      0.555128      1.532111
# std          139.778094  1.000006e+00      0.496954      1.234365
# min            3.000000 -3.930804e+00      0.000000      0.000000
# 25%          128.000000 -5.182492e-02      0.000000      1.000000
# 50%          241.000000 -4.343282e-02      1.000000      1.000000
# 75%          357.000000 -2.236279e-02      1.000000      3.000000
# max          492.000000  1.426454e+02      1.000000      6.000000
#
#        DUPLICATEFLAG  TRANSACTIONCODE  RESPONSECODEOUT  REVERSALFLAG  \
# count   90017.000000     90017.000000     90017.000000  90017.000000
# mean        0.000011     31941.382606         0.196130      0.005754
# std         0.003333    140531.938709         7.360145      0.075640
# min         0.000000         0.000000         0.000000      0.000000
# 25%         0.000000      2000.000000         0.000000      0.000000
# 50%         0.000000      2000.000000         0.000000      0.000000
# 75%         0.000000      3000.000000         0.000000      0.000000
# max         1.000000    911000.000000      2012.000000      1.000000
#
#        ADJUSTMENTFLAG  ORIGINALAMOUNT   TRANSUBTYPE  OURPREAUTHCODE  \
# count    90017.000000    90017.000000  90017.000000    90017.000000
# mean         0.010709        0.429333      9.533477        1.530411
# std          0.102930       14.787008      4.441568        1.206131
# min          0.000000        0.000000      0.000000        0.000000
# 25%          0.000000        0.000000      9.000000        1.000000
# 50%          0.000000        0.000000     11.000000        1.000000
# 75%          0.000000        0.000000     13.000000        3.000000
# max          1.000000     2233.090000     13.000000        3.000000
#
#        OURRESPONSECODE     FORCEPOST  CURRENCYAMOUNT  ISAFEEAMOUNT  \
# count     90017.000000  90017.000000    90017.000000  90017.000000
# mean         30.367331      0.401169        0.391550      0.008103
# std         242.753371      0.490138      117.476106      0.308410
# min           0.000000      0.000000        0.000000     -4.950000
# 25%           0.000000      0.000000        0.000000      0.000000
# 50%           0.000000      0.000000        0.000000      0.000000
# 75%           0.000000      1.000000        0.000000      0.000000
# max        2076.000000      1.000000    35246.160000     58.530000
#
#        CASHBACKAMOUNT     FraudFlag
# count    90017.000000  90017.000000
# mean         0.320509      0.000689
# std          3.869722      0.026235
# min          0.000000      0.000000
# 25%          0.000000      0.000000
# 50%          0.000000      0.000000
# 75%          0.000000      0.000000
# max        300.000000      1.000000

# %%
# split the data into training set (80%) and test set (20%)

normal = dfn.loc[dfn.FraudFlag == 0]
frauds = dfn.loc[dfn.FraudFlag == 1]

X_train, X_test = train_test_split(normal, test_size=0.2, random_state=RANDOM_SEED)
X_train, X_valid = train_test_split(X_train, test_size=0.2, random_state=RANDOM_SEED)

# %%
# add the fraud cases to test set and validation set
X_test = X_test.append(frauds)[0:30]
X_valid = X_valid.append(frauds)[30:]

# drop the class feature on the test data
y_test = X_test['FraudFlag']
y_valid = X_valid['FraudFlag']

X_train = X_train.drop(['FraudFlag'], axis=1)
X_test = X_test.drop(['FraudFlag'], axis=1)
X_valid = X_valid.drop(['FraudFlag'], axis=1)

# %%
X_train = X_train.values
X_test = X_test.values
X_valid = X_valid.values

# %%
input_dim = X_train.shape[1] # number of features
input_dim
# Out:
# 17

# %%
# num neurons in first encoding layer
encoding_dim = 12 

# input layer
input_layer = Input(shape=(input_dim, ))

# 12 neuron encoding layer
encoder = Dense(encoding_dim, activation='tanh',
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
# 6 neuron encoding layer
encoder = Dense(int(encoding_dim / 2), activation='relu')(encoder)

# 6 neuron decoding layer
decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)

# 17 layer decoding layer (output layer, predicts all features)
decoder = Dense(input_dim, activation='relu')(decoder)

# %%
# put it all together
autoencoder = Model(inputs=input_layer, outputs=decoder)

model_id = str(uuid.uuid4())
model_filepath = './checkpoints/autoencoder_' + model_id + '.h5'

# %%
nb_epoch = 10 # number of iterations over the entire training data
batch_size = 32 # number of samples per gradient update

# %%
autoencoder.compile(optimizer='adam',
                    loss='mean_squared_error',
                    metrics=['accuracy'])

# %%
checkpointer = ModelCheckpoint(filepath='./checkpoints/autoencoder.h5',
                               verbose=0,
                               save_best_only=True)

# %%
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

# %%
# fit the model to itself
history = autoencoder.fit(X_train, X_train,
                         epochs=nb_epoch,
                         batch_size=batch_size,
                         shuffle=True,
                         validation_data=(X_valid,X_valid),
                         verbose=1,
                         callbacks=[checkpointer, tensorboard]).history
# Out:
# Train on 57571 samples, validate on 14425 samples
# Epoch 1/10
# 57571/57571 [==============================] - 3s 52us/step - loss: 1224933828.5492 - acc: 0.8628 - val_loss: 1210544720.7967 - val_acc: 0.0029
# Epoch 2/10
# 57571/57571 [==============================] - 3s 49us/step - loss: 1224894212.6720 - acc: 0.0037 - val_loss: 1210506587.7656 - val_acc: 0.0029
# Epoch 3/10
# 57571/57571 [==============================] - 3s 48us/step - loss: 1224855822.7134 - acc: 0.0037 - val_loss: 1210468954.1856 - val_acc: 0.0029
# Epoch 4/10
# 57571/57571 [==============================] - 3s 48us/step - loss: 1224817892.5531 - acc: 0.0037 - val_loss: 1210431805.6478 - val_acc: 0.0029
# Epoch 5/10
# 57571/57571 [==============================] - 3s 48us/step - loss: 1224779815.4249 - acc: 0.0037 - val_loss: 1210394016.5420 - val_acc: 0.0029
# Epoch 6/10
# 57571/57571 [==============================] - 3s 50us/step - loss: 1224741996.0784 - acc: 0.0037 - val_loss: 1210356829.8759 - val_acc: 0.0029
# Epoch 7/10
# 57571/57571 [==============================] - 3s 53us/step - loss: 1224704482.9113 - acc: 0.0037 - val_loss: 1210319837.0346 - val_acc: 0.0029
# Epoch 8/10
# 57571/57571 [==============================] - 3s 53us/step - loss: 1224667094.8637 - acc: 0.0037 - val_loss: 1210282945.3649 - val_acc: 0.0029
# Epoch 9/10
# 57571/57571 [==============================] - 3s 48us/step - loss: 1224629533.6569 - acc: 0.0037 - val_loss: 1210245509.1120 - val_acc: 0.0029
# Epoch 10/10
# 57571/57571 [==============================] - 3s 47us/step - loss: 1224591599.5599 - acc: 0.0037 - val_loss: 1210208161.8072 - val_acc: 0.0029

# %%
history_filepath = './checkpoints/autoencoder_history_' + model_id
with open(history_filepath, 'wb') as file_pi:
    pickle.dump(history, file_pi)

# %%
# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
predictions = autoencoder.predict(X_test)

# %%
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})

# %%
error_df.describe()

# %%
# reconstruct error without fraud

fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fraud_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(fraud_error_df.reconstruction_error.values, bins=10)

# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()

# %%
threshold = 2.9

groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.ylim([])
plt.show();

# %%
error_df.reconstruction_error

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)

plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
df.loc['POSTAMOUNT'] = np.log(np.abs(df['POSTAMOUNT'] + 1))

# %%
neg = df.index[df['POSTAMOUNT'] < 0]
df
# Out:
#             PROCESSORACCOUNT    OURACCOUNT  POSTAMOUNT  POSTSUCCESS  \
# 0               4.888889e+15  3.243617e+09    3.931826          0.0
# 1               4.888884e+15  6.585870e+09    3.931826          1.0
# 2               4.888887e+15  1.898540e+09    6.061457          0.0
# 3               4.888887e+15  1.898540e+09    5.257704          0.0
# 4               4.888887e+15  1.898540e+09    3.574590          0.0
# 5               4.888889e+15  3.243617e+09    4.615121          1.0
# 6               4.888889e+15  3.243617e+09    3.713572          1.0
# 7               4.888889e+15  3.243617e+09    5.707110          1.0
# 8               4.888889e+15  3.243617e+09    4.615121          1.0
# 9               4.888889e+15  3.243617e+09    5.707110          1.0
# 10              4.888889e+15  3.243617e+09    5.707110          1.0
# 11              4.888889e+15  3.243617e+09    5.707110          1.0
# 12              4.888889e+15  3.243617e+09    5.303305          1.0
# 13              4.888889e+15  3.243617e+09    5.707110          1.0
# 14              4.888889e+15  3.243617e+09    5.564520          1.0
# 15              4.888889e+15  3.243617e+09    5.398163          1.0
# 16              4.888889e+15  3.243617e+09    5.303305          1.0
# 17              4.888889e+15  3.243617e+09    5.707110          1.0
# 18              4.888889e+15  3.243617e+09    3.044522          1.0
# 19              4.888889e+15  3.243617e+09    5.707110          1.0
# 20              4.888889e+15  3.243617e+09    5.707110          1.0
# 21              4.888889e+15  3.243617e+09    5.303305          1.0
# 22              4.888889e+15  3.243617e+09    5.707110          1.0
# 23              4.888889e+15  3.243617e+09    5.638355          1.0
# 24              4.888889e+15  3.243617e+09    5.707110          1.0
# 25              4.888889e+15  3.243617e+09    5.993961          1.0
# 26              4.888889e+15  3.243617e+09    5.638355          1.0
# 27              4.888889e+15  3.243617e+09    5.564520          1.0
# 28              4.888889e+15  3.243617e+09    5.707110          1.0
# 29              4.888889e+15  3.243617e+09    5.564520          1.0
# ...                      ...           ...         ...          ...
# 89988           4.888888e+15  8.605921e+09    3.258097          1.0
# 89989           4.888888e+15  1.618334e+09    0.000000          0.0
# 89990           4.888888e+15  1.618334e+09    6.398595          1.0
# 89991           4.888888e+15  1.618334e+09    0.000000          0.0
# 89992           4.888888e+15  9.699990e+09    0.000000          0.0
# 89993           4.888888e+15  9.699990e+09    0.000000          0.0
# 89994           4.888888e+15  9.699990e+09    0.000000          0.0
# 89995           4.888888e+15  9.699990e+09    0.000000          0.0
# 89996           4.888888e+15  9.699990e+09    0.000000          0.0
# 89997           4.888888e+15  9.699990e+09    0.000000          0.0
# 89998           4.888888e+15  9.699990e+09    4.262680          1.0
# 89999           4.888888e+15  9.699990e+09    0.000000          0.0
# 90000           4.888888e+15  9.699990e+09    0.000000          0.0
# 90001           4.888888e+15  9.699990e+09    0.000000          0.0
# 90002           4.888888e+15  9.699990e+09    0.000000          0.0
# 90003           4.888888e+15  9.699990e+09    1.061257          1.0
# 90004           4.888888e+15  9.699990e+09    0.000000          0.0
# 90005           4.888888e+15  9.699990e+09    0.000000          0.0
# 90006           4.888888e+15  9.699990e+09    0.000000          0.0
# 90007           4.888888e+15  9.699990e+09    0.000000          0.0
# 90008           4.888888e+15  9.699990e+09    4.940928          1.0
# 90009           4.888888e+15  9.699990e+09    0.000000          0.0
# 90010           4.888888e+15  9.699990e+09    0.000000          0.0
# 90011           4.888888e+15  9.699990e+09    0.000000          0.0
# 90012           4.888888e+15  9.699990e+09    0.000000          0.0
# 90013           4.888888e+15  9.699990e+09    4.976734          1.0
# 90014           4.888888e+15  9.699990e+09    0.000000          0.0
# 90015           4.888888e+15  9.699990e+09    0.000000          0.0
# 90016           4.888888e+15  9.699990e+09    0.000000          0.0
# POSTAMOUNT               NaN           NaN         NaN          NaN
#
#             HOLDACTION  DUPLICATEFLAG  TRANSACTIONCODE RESPONSECODEIN  \
# 0                  0.0            0.0           2000.0            NaN
# 1                  0.0            0.0           2000.0            NaN
# 2                  1.0            0.0           3000.0            NaN
# 3                  1.0            0.0           3000.0            NaN
# 4                  1.0            0.0           3000.0            NaN
# 5                  0.0            0.0          12000.0            NaN
# 6                  0.0            0.0          12000.0            NaN
# 7                  0.0            0.0          12000.0            NaN
# 8                  0.0            0.0          12000.0            NaN
# 9                  0.0            0.0          12000.0            NaN
# 10                 0.0            0.0          12000.0            NaN
# 11                 0.0            0.0          12000.0            NaN
# 12                 0.0            0.0          12000.0            NaN
# 13                 0.0            0.0          12000.0            NaN
# 14                 0.0            0.0          12000.0            NaN
# 15                 0.0            0.0          12000.0            NaN
# 16                 0.0            0.0          12000.0            NaN
# 17                 0.0            0.0          12000.0            NaN
# 18                 0.0            0.0          12000.0            NaN
# 19                 0.0            0.0          12000.0            NaN
# 20                 0.0            0.0          12000.0            NaN
# 21                 0.0            0.0          12000.0            NaN
# 22                 0.0            0.0          12000.0            NaN
# 23                 0.0            0.0          12000.0            NaN
# 24                 0.0            0.0          12000.0            NaN
# 25                 0.0            0.0          12000.0            NaN
# 26                 0.0            0.0          12000.0            NaN
# 27                 0.0            0.0          12000.0            NaN
# 28                 0.0            0.0          12000.0            NaN
# 29                 0.0            0.0          12000.0            NaN
# ...                ...            ...              ...            ...
# 89988              0.0            0.0         210010.0            NaN
# 89989              0.0            0.0         910000.0            NaN
# 89990              0.0            0.0         210010.0            NaN
# 89991              0.0            0.0         910000.0            NaN
# 89992              0.0            0.0         910000.0            NaN
# 89993              0.0            0.0         390000.0            NaN
# 89994              0.0            0.0         910000.0            NaN
# 89995              0.0            0.0         390000.0            NaN
# 89996              0.0            0.0         910000.0            NaN
# 89997              0.0            0.0         390000.0            NaN
# 89998              0.0            0.0         210010.0            NaN
# 89999              0.0            0.0         910000.0            NaN
# 90000              0.0            0.0         390000.0            NaN
# 90001              0.0            0.0         910000.0            NaN
# 90002              0.0            0.0         390000.0            NaN
# 90003              0.0            0.0         210010.0            NaN
# 90004              0.0            0.0         910000.0            NaN
# 90005              0.0            0.0         390000.0            NaN
# 90006              0.0            0.0         910000.0            NaN
# 90007              0.0            0.0         390000.0            NaN
# 90008              0.0            0.0         210010.0            NaN
# 90009              0.0            0.0         910000.0            NaN
# 90010              0.0            0.0         390000.0            NaN
# 90011              0.0            0.0         910000.0            NaN
# 90012              0.0            0.0         390000.0            NaN
# 90013              0.0            0.0         210010.0            NaN
# 90014              0.0            0.0         910000.0            NaN
# 90015              0.0            0.0         390000.0            NaN
# 90016              0.0            0.0         910000.0            NaN
# POSTAMOUNT         NaN            NaN              NaN            NaN
#
#             RESPONSECODEOUT AUTHIDRESPONSE    ...      CCAFEEAMOUNT  \
# 0                    2012.0         012461    ...               0.0
# 1                       0.0         012461    ...               0.0
# 2                       0.0         042316    ...               0.0
# 3                       0.0         042316    ...               0.0
# 4                       0.0         042316    ...               0.0
# 5                       0.0         050544    ...               0.0
# 6                       0.0         082055    ...               0.0
# 7                       0.0         064202    ...               0.0
# 8                       0.0         012246    ...               0.0
# 9                       0.0         014831    ...               0.0
# 10                      0.0         093751    ...               0.0
# 11                      0.0         051853    ...               0.0
# 12                      0.0         012851    ...               0.0
# 13                      0.0         072040    ...               0.0
# 14                      0.0         044433    ...               0.0
# 15                      0.0         051126    ...               0.0
# 16                      0.0         051418    ...               0.0
# 17                      0.0         051505    ...               0.0
# 18                      0.0         051309    ...               0.0
# 19                      0.0         011329    ...               0.0
# 20                      0.0         050844    ...               0.0
# 21                      0.0         052134    ...               0.0
# 22                      0.0         011816    ...               0.0
# 23                      0.0         051538    ...               0.0
# 24                      0.0         051232    ...               0.0
# 25                      0.0         051401    ...               0.0
# 26                      0.0         051647    ...               0.0
# 27                      0.0         064300    ...               0.0
# 28                      0.0         051436    ...               0.0
# 29                      0.0         063948    ...               0.0
# ...                     ...            ...    ...               ...
# 89988                   0.0            NaN    ...               0.0
# 89989                   0.0         012721    ...               0.0
# 89990                   0.0            NaN    ...               0.0
# 89991                   0.0         012915    ...               0.0
# 89992                   0.0         001914    ...               0.0
# 89993                   0.0            NaN    ...               0.0
# 89994                   0.0         001915    ...               0.0
# 89995                   0.0            NaN    ...               0.0
# 89996                   0.0         024946    ...               0.0
# 89997                   0.0            NaN    ...               0.0
# 89998                   0.0            NaN    ...               0.0
# 89999                   0.0         025039    ...               0.0
# 90000                   0.0            NaN    ...               0.0
# 90001                   0.0         002654    ...               0.0
# 90002                   0.0            NaN    ...               0.0
# 90003                   0.0            NaN    ...               0.0
# 90004                   0.0         002742    ...               0.0
# 90005                   0.0            NaN    ...               0.0
# 90006                   0.0         063158    ...               0.0
# 90007                   0.0            NaN    ...               0.0
# 90008                   0.0            NaN    ...               0.0
# 90009                   0.0         063242    ...               0.0
# 90010                   0.0            NaN    ...               0.0
# 90011                   0.0         023753    ...               0.0
# 90012                   0.0            NaN    ...               0.0
# 90013                   0.0            NaN    ...               0.0
# 90014                   0.0         023855    ...               0.0
# 90015                   0.0            NaN    ...               0.0
# 90016                   0.0         081056    ...               0.0
# POSTAMOUNT              NaN            NaN    ...               NaN
#
#            ICAFEEAMOUNT CASHBACKAMOUNT  CARDACCEPTORCITY  CARDACCEPTORCOUNTRY  \
# 0                   0.0            0.0       FORT WRIGHT                   US
# 1                   0.0            0.0       FORT WRIGHT                   US
# 2                   0.0            0.0            DEWITT                   US
# 3                   0.0            0.0            DEWITT                   US
# 4                   0.0            0.0             MASON                   US
# 5                   0.0            0.0      EAST LANSING                   US
# 6                   0.0            0.0              HOLT                   US
# 7                   0.0            0.0      EAST LANSING                   US
# 8                   0.0            0.0      EAST LANSING                   US
# 9                   0.0            0.0             MASON                   US
# 10                  0.0            0.0     MACKINAW CITY                   US
# 11                  0.0            0.0      EAST LANSING                   US
# 12                  0.0            0.0             MASON                   US
# 13                  0.0            0.0             MASON                   US
# 14                  0.0            0.0      EAST LANSING                   US
# 15                  0.0            0.0      EAST LANSING                   US
# 16                  0.0            0.0      EAST LANSING                   US
# 17                  0.0            0.0      EAST LANSING                   US
# 18                  0.0            0.0      EAST LANSING                   US
# 19                  0.0            0.0      EAST LANSING                   US
# 20                  0.0            0.0      EAST LANSING                   US
# 21                  0.0            0.0      EAST LANSING                   US
# 22                  0.0            0.0      EAST LANSING                   US
# 23                  0.0            0.0      EAST LANSING                   US
# 24                  0.0            0.0      EAST LANSING                   US
# 25                  0.0            0.0      EAST LANSING                   US
# 26                  0.0            0.0      EAST LANSING                   US
# 27                  0.0            0.0      EAST LANSING                   US
# 28                  0.0            0.0      EAST LANSING                   US
# 29                  0.0            0.0      EAST LANSING                   US
# ...                 ...            ...               ...                  ...
# 89988               0.0            0.0      East Lansing                   US
# 89989               0.0            0.0             AKRON                   US
# 89990               0.0            0.0             AKRON                   US
# 89991               0.0            0.0             AKRON                   US
# 89992               0.0            0.0      East Lansing                   US
# 89993               0.0            0.0      East Lansing                   US
# 89994               0.0            0.0      East Lansing                   US
# 89995               0.0            0.0      East Lansing                   US
# 89996               0.0            0.0      East Lansing                   US
# 89997               0.0            0.0      East Lansing                   US
# 89998               0.0            0.0      East Lansing                   US
# 89999               0.0            0.0      East Lansing                   US
# 90000               0.0            0.0      East Lansing                   US
# 90001               0.0            0.0      East Lansing                   US
# 90002               0.0            0.0      East Lansing                   US
# 90003               0.0            0.0      East Lansing                   US
# 90004               0.0            0.0      East Lansing                   US
# 90005               0.0            0.0      East Lansing                   US
# 90006               0.0            0.0      East Lansing                   US
# 90007               0.0            0.0      East Lansing                   US
# 90008               0.0            0.0      East Lansing                   US
# 90009               0.0            0.0      East Lansing                   US
# 90010               0.0            0.0      East Lansing                   US
# 90011               0.0            0.0      East Lansing                   US
# 90012               0.0            0.0      East Lansing                   US
# 90013               0.0            0.0      East Lansing                   US
# 90014               0.0            0.0      East Lansing                   US
# 90015               0.0            0.0      East Lansing                   US
# 90016               0.0            0.0      East Lansing                   US
# POSTAMOUNT          NaN            NaN               NaN                  NaN
#
#             CARDACCEPTORIDCODE           CARDACCEPTORNAME  CARDACCEPTORSTATE  \
# 0                   7660002867  WAL Wal-Mart Store 441780                 KY
# 1                   7660002867  WAL Wal-Mart Store 441780                 KY
# 2                4445000548644             US MEIJER #209                 MI
# 3                4445000548644             US MEIJER #209                 MI
# 4              542929809022346      US SPEEDWAY 02234 N C                 MI
# 5               MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 6                CO-OP NETWORK                 7ELEVEN-FC                 MI
# 7               MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 8               MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 9               MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 10               CO-OP NETWORK           STRAITS AREA FCU                 MI
# 11              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 12              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 13              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 14              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 15              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 16              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 17              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 18              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 19              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 20              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 21              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 22              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 23              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 24              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 25              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 26              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 27              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 28              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# 29              MICHIGAN STATE    MICHIGAN STATE UNIV FCU                 MI
# ...                        ...                        ...                ...
# 89988          0123456789ABCDE                   eDeposit                 MI
# 89989                  Towpath       Towpath Credit Union                 OH
# 89990                  Towpath       Towpath Credit Union                 OH
# 89991                  Towpath       Towpath Credit Union                 OH
# 89992                 00099352                   eDeposit                 MI
# 89993                 00099352                   eDeposit                 MI
# 89994                 00099352                   eDeposit                 MI
# 89995                 00099352                   eDeposit                 MI
# 89996          0123456789ABCDE                   eDeposit                 MI
# 89997          0123456789ABCDE                   eDeposit                 MI
# 89998          0123456789ABCDE                   eDeposit                 MI
# 89999          0123456789ABCDE                   eDeposit                 MI
# 90000          0123456789ABCDE                   eDeposit                 MI
# 90001          0123456789ABCDE                   eDeposit                 MI
# 90002          0123456789ABCDE                   eDeposit                 MI
# 90003          0123456789ABCDE                   eDeposit                 MI
# 90004          0123456789ABCDE                   eDeposit                 MI
# 90005          0123456789ABCDE                   eDeposit                 MI
# 90006          0123456789ABCDE                   eDeposit                 MI
# 90007          0123456789ABCDE                   eDeposit                 MI
# 90008          0123456789ABCDE                   eDeposit                 MI
# 90009          0123456789ABCDE                   eDeposit                 MI
# 90010          0123456789ABCDE                   eDeposit                 MI
# 90011          0123456789ABCDE                   eDeposit                 MI
# 90012          0123456789ABCDE                   eDeposit                 MI
# 90013          0123456789ABCDE                   eDeposit                 MI
# 90014          0123456789ABCDE                   eDeposit                 MI
# 90015          0123456789ABCDE                   eDeposit                 MI
# 90016          0123456789ABCDE                   eDeposit                 MI
# POSTAMOUNT                 NaN                        NaN                NaN
#
#              CARDACCEPTORSTREET  FraudFlag
# 0             3450 VALLEY PLAZA        1.0
# 1             3450 VALLEY PLAZA        1.0
# 2                   MEIJER #209        1.0
# 3                   MEIJER #209        1.0
# 4            SPEEDWAY 02234 N C        1.0
# 5            3775 COOLIDGE ROAD        0.0
# 6              1997 AURELIUS RD        0.0
# 7            3775 COOLIDGE ROAD        0.0
# 8                3777 WEST ROAD        0.0
# 9               1133 S CEDAR ST        0.0
# 10          121 E. CENTRAL AVE.        0.0
# 11           3775 COOLIDGE ROAD        0.0
# 12                 1133 S CEDAR        0.0
# 13                 1133 S CEDAR        0.0
# 14           3775 COOLIDGE ROAD        0.0
# 15           3775 COOLIDGE ROAD        0.0
# 16           3775 COOLIDGE ROAD        0.0
# 17           3775 COOLIDGE ROAD        0.0
# 18           3775 COOLIDGE ROAD        0.0
# 19               3777 WEST ROAD        0.0
# 20           3775 COOLIDGE ROAD        0.0
# 21           3775 COOLIDGE ROAD        0.0
# 22               3777 WEST ROAD        0.0
# 23               3777 WEST ROAD        0.0
# 24               3777 WEST ROAD        0.0
# 25           3775 COOLIDGE ROAD        0.0
# 26           3775 COOLIDGE ROAD        0.0
# 27           3775 COOLIDGE ROAD        0.0
# 28           3775 COOLIDGE ROAD        0.0
# 29           3775 COOLIDGE ROAD        0.0
# ...                         ...        ...
# 89988             MSUFCU Mobile        0.0
# 89989           2969 SMITH ROAD        0.0
# 89990           2969 SMITH ROAD        0.0
# 89991           2969 SMITH ROAD        0.0
# 89992             MSUFCU Mobile        0.0
# 89993             MSUFCU Mobile        0.0
# 89994             MSUFCU Mobile        0.0
# 89995             MSUFCU Mobile        0.0
# 89996             MSUFCU Mobile        0.0
# 89997             MSUFCU Mobile        0.0
# 89998             MSUFCU Mobile        0.0
# 89999             MSUFCU Mobile        0.0
# 90000             MSUFCU Mobile        0.0
# 90001             MSUFCU Mobile        0.0
# 90002             MSUFCU Mobile        0.0
# 90003             MSUFCU Mobile        0.0
# 90004             MSUFCU Mobile        0.0
# 90005             MSUFCU Mobile        0.0
# 90006             MSUFCU Mobile        0.0
# 90007             MSUFCU Mobile        0.0
# 90008             MSUFCU Mobile        0.0
# 90009             MSUFCU Mobile        0.0
# 90010             MSUFCU Mobile        0.0
# 90011             MSUFCU Mobile        0.0
# 90012             MSUFCU Mobile        0.0
# 90013             MSUFCU Mobile        0.0
# 90014             MSUFCU Mobile        0.0
# 90015             MSUFCU Mobile        0.0
# 90016             MSUFCU Mobile        0.0
# POSTAMOUNT                  NaN        NaN
#
# [90018 rows x 39 columns]

# %%
# Out:
# /Users/paulsoma/anaconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# -inf
